# %%
import ROOT
from root_numpy import root2array, tree2array, root2rec, testdata
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import minimize # MINIMIZATION
import copy

# %% [markdown]
# ## Prepare data structure and functions for single tracking

# %% [markdown]
# ### Line

# %%
class Line:
    def __init__(self, x=0, y=0, z=0, dx=0, dy=0, dz=0, point=[], direction=[], params=[], det_id=0):
        if len(params) == 6:
            self.x,  self.y,  self.z  = params[:3] 
            self.dx, self.dy, self.dz = params[3:]
        elif len(point) == 3 and len(direction) == 3:
            self.x,  self.y,  self.z  = point
            self.dx, self.dy, self.dz = direction
        else:
            self.x,  self.y,  self.z  =  x,  y,  z
            self.dx, self.dy, self.dz = dx, dy, dz
        
        # just to make this line a detector Line
        self.det_id = int(det_id)

    def __repr__(self):
        return "Line: det = {}\t p = ({:.3f}, {:.3f}, {:.3f})\t v = [{:.3f}, {:.3f}, {:.3f}]".format(
            self.det_id, self.x, self.y, self.z, self.dx, self.dy, self.dz
        )
            
    def distance(self, other):
        n_vector = np.cross(self.line_vector(), other.line_vector())
        s_o_vector = np.array([self.x - other.x, self.y - other.y, self.z - other.z])
        return np.linalg.norm( np.dot(n_vector, s_o_vector) ) / np.linalg.norm(n_vector)

    def line_vector(self):
        return np.array([self.dx, self.dy, self.dz])

# %% [markdown]
# ### Open root file

# %%
geometry_root = root2array('det_geometry.root', 'T')
reco_flat = root2array('reco_10k_flat.root', 'T')

# %% [markdown]
# ### Prepare dataframes

# %%
geom_df = pd.DataFrame(geometry_root) 
df_all  = pd.DataFrame(reco_flat)

single_df = df_all.loc[(df_all['uLineSize'] == 1) & (df_all['vLineSize'] == 1)]     # OLNY RPS WITH SINGLE TRACKING
single_groups_df = single_df[['eventID', 'groupID', 'rpID']]\
    .drop_duplicates()\
    .groupby(['eventID', 'groupID'])\
    .size()\
    .reset_index(name='counts')
single_groups_df = single_groups_df.loc[(single_groups_df['counts'] == 3)]          # ONLY HITS WHERE ALL RPS 
                                                                                    # FROM GROUP WAS HIT

print("all tracks shape: {}".format(df_all.shape))
print("single tracking shape: {}".format(single_df.shape))
print("single_groups shape: {}".format(single_groups_df.shape))
# Out:
# all tracks shape: (569625, 10)
# single tracking shape: (502443, 10)
# single_groups shape: (15320, 3)

# %% [markdown]
# ### Apply fiducials to detector: Move center by [dx, dy] defined in Geometry/TotemRPData/data/RP_Hybrid.xml

# %%
class Direction:
    '''
    Wektor jednostkowy
    '''
    def __init__(self, dx=1.0, dy=0.0):
        self.dx = dx
        self.dy = dy
    
    def __repr__(self):
        return "dx = {}\tdy={}".format(self.dx, self.dy)

    def get_perpendicular(self):
        return Direction(self.dy, -self.dx)
        
    
class Vector2D:
    def __init__(self, x=0.0, y=0.0, start=None, end=None):
        if start is None or end is None:
            self.x = x
            self.y = y
        else:
            self.x = end.x - start.x
            self.y = end.y - start.y
                 
    def __repr__(self):
        return "x = {}\ty = {}".format(self.x, self.y)
    

class Point2D:
    def __init__(self, x=0.0, y=0.0):
        self.x = x
        self.y = y
    
    def __repr__(self):
        return "x = {}\ty = {}".format(self.x, self.y)
    
    def move(self, vector):
        self.x += vector.x
        self.y += vector.y
    
    def rotate_around_point(self, other, direction):
        s = direction.dy
        c = direction.dx
        
        new_x = c * (self.x - other.x) - s * (self.y - other.y) + other.x
        new_y = s * (self.x - other.x) + c * (self.y - other.y) + other.y
    
        self.x = new_x
        self.y = new_y

        
class RPSilicon:
    
    RP_Det_Fid_Top_a   = 0.301  # [mm]
    RP_Det_Fid_Top_b   = 1.0275 # [mm]
    RP_Det_Fid_Left_a  = 0.301  # [mm]
    RP_Det_Fid_Left_c  = 0.2985 # [mm]
    RP_Det_Fid_Right_b = 1.0275 # [mm]
    RP_Det_Fid_Right_d = 1.0255 # [mm]

    RP_Det_dx_0 = ( RP_Det_Fid_Left_c  -  RP_Det_Fid_Right_b) / 2.0 # [mm]
    RP_Det_dy_0 = ( RP_Det_Fid_Right_d  -  RP_Det_Fid_Left_a) / 2.0
    
    def __init__(self, center, direction, siId):
        self.center = center
        self.direction = direction
        self.siId = siId
        
        fid_center = copy.deepcopy(self.center)
        fid_center.move(Vector2D(RPSilicon.RP_Det_dx_0, RPSilicon.RP_Det_dy_0))
        fid_center.rotate_around_point(self.center, self.get_rot_direction())
        
        self.fid_center = fid_center
    
    def get_rot_direction(self):
        arm = int(self.siId / 1000) 
        if   arm == 0 and self.siId % 2 == 0:  
            return self.direction
        elif arm == 0 and self.siId % 2 == 1:
            return Direction(self.direction.dy, -self.direction.dx)
        elif arm == 1 and self.siId % 2 == 0:
            return Direction(self.direction.dy, -self.direction.dx)
        else:
            return self.direction

# %% [markdown]
# ### Create hit lines for given hits dataframe

# %%
DET_Z_TRANSLATION = 0 # SET WITHIN EVENT PROCESSING


def get_hit_lines(single_hits_df, geom_df):
    '''
        reco_0_flat.root:     recoID  eventID  armID  groupID  rpID  uLineSize  vLineSize  siliconID   position  sigma_
        det_geometry.root:    detId   x        y      z        dx    dy
    '''
    
    hit_lines = []

    for h_index, h_row in single_hits_df.iterrows():
        
        h_position = h_row['position']
        det_ID = 10 * h_row['rpID'] + h_row['siliconID']        
        det_info = geom_df.loc[(geom_df['detId'] == det_ID)].iloc[0]
    
        rp_silicon = RPSilicon(Point2D(det_info['x'], det_info['y']), Direction(dx=det_info['dx'], dy=det_info['dy']), det_ID)
        
        x = rp_silicon.fid_center.x + h_position * det_info['dx']    # was: det_info['x'], but now: fiducial included [mm]
        y = rp_silicon.fid_center.y + h_position * det_info['dy']    # was: det_info['y'], but now: fiducial included [mm] 
        
        z = det_info['z'] * 1000 + DET_Z_TRANSLATION     # z [mm] with translation to operate on smaller numbers
        dx = - det_info['dy']  
        dy = det_info['dx'] 
        dz = 0
        
        new_line = Line(x, y, z, dx, dy, dz, det_id=det_ID)
        hit_lines.append(new_line)
        
    return hit_lines

# %% [markdown]
# ### Printing fitting solution

# %%
class Hit:
    def __init__(self, x=0, y=0, z=0):
        self.x = x
        self.y = y
        self.z = z


def print_pretty_solution(solution, geom_df):
    print("FULL SOLUTION: \n{}".format(solution))
    print("Sum of distances: {}".format(solution.fun))
    print("Solution: [\n\tx = {}\n\ty = {} \n\tz = {} \n\tdx = {} \n\tdy = {} \n\tdz = {} ]".format(
        solution.x[0],
        solution.x[1],
        solution.x[2], # - DET_Z_TRANSLATION,
        solution.x[3],
        solution.x[4],
        solution.x[5])
    )
    print("]")
    print("\nDistances from detector lines and hit position")
    print("ID\tDistance from hit line [mm]\t x [mm]\t\ty [mm]\t\tz [m]")

    plane_hit = Hit()

    for line in LINE_SET:
        sol_x, sol_y, sol_z = solution.x[0], solution.x[1], solution.x[2]
        sol_dx, sol_dy, sol_dz = solution.x[3], solution.x[4], solution.x[5]
        
        det_info = geom_df.loc[(geom_df['detId'] == line.det_id)].iloc[0]
        det_z = det_info['z']
        k = (det_z - (sol_z - DET_Z_TRANSLATION)) / sol_dz
        
        plane_hit.x = sol_x + k * sol_dx
        plane_hit.y = sol_y + k * sol_dy
        plane_hit.z = det_z

        print("{}\t{:.5f}\t\t\t\t({:.5f}\t{:.5f}\t{})".format(line.det_id,
                                                              Line(params=solution.x).distance(line),
                                                              plane_hit.x,
                                                              plane_hit.y,
                                                              plane_hit.z))
    print("\n")

# %% [markdown]
# ## Minimization for each rp group where is single-tracking

# %% [markdown]
# ### Chi 2

# %%
'''
    Chi^2 = Sum ( (O_i - E_i) / sigma_i ) ^ 2
    
    E_i - Expected value (We want distance to hit line = 0)
    O_i - Observed value (Actual distance to hit line)
    
    sigma_i =
        a) sigma from DataFormats/TotemRPDataTypes/interface/RPRecoHit.h
        b) sigma as a distances between two strips - 0.0659
        c) sqrt( Sum[(x_i - u)^2] / N )
            x_i - i-th distance from hit line
            u   - average distance from hit line
'''

# REQUIRED BY MY CHI2 FUNCTION
LINE_SET = []

# SIGMA = 0.0191  # a)
SIGMA = 0.0659  # b)

def chi2(params):
    line = Line(params=params)                                                        # CREATING FITTED LINE FROM PARAMS
    return np.sum([np.power( line.distance(other) / SIGMA, 2) for other in LINE_SET]) # SUM OF DISTANCES

# c)
def get_sigma(params):
    line = Line(params=params)
    distances = np.array([line.distance(other) for other in LINE_SET])
    
    u = np.average(distances)
    N = len(distances)
    u_diff = np.array([dist - u for dist in distances])
    
    return np.sqrt( np.sum(np.power(u_diff, 2.0)) / len(distances) )

def chi2_wiki(params):
    line = Line(params=params)
    sigma = get_sigma(params)
    return np.sum([np.power( line.distance(other) / sigma, 2) for other in LINE_SET])

# %% [markdown]
# ### Minimization

# %%
# OBJECTIVE FUNCTION
def objective(params):
    line = Line(params=params)                                  # CREATING FITTED LINE FROM PARAMS
    return np.sum([line.distance(other) for other in LINE_SET]) # SUM OF DISTANCES

# SEED FOR MINIMIZING
def get_x0(first_hit_info, geom_df):    
    det_id   = first_hit_info['rpID'] * 10 + first_hit_info['siliconID'] 
    det_info = geom_df.loc[(geom_df['detId'] == det_id)].iloc[0]
    
    det_x = 0.0 # det_info['x']
    det_y = 0.0 # det_info['y']
    det_z = det_info['z'] * 1000 + DET_Z_TRANSLATION 
    
    return [det_x, det_y, det_z, 0.1, 0.1, np.sign(det_z)]

def get_constraints():
    def constraint1(params):
        return 1.0 - np.sum([dir**2 for dir in params[3:]]) # dx^2 + dy^2 + dz^2 = 1

    con1 = {'type': 'eq', 'fun':constraint1}
    return [con1]

# BOUNDS FOR PARAMETERS
def get_bounds():
    b_x   = (   -50.0,    50.0)
    b_y   = (   -50.0,    50.0)
    b_z   = (-20000.0, 20000.0)
    b_dir = (    -1.0,     1.0)
    return (b_x, b_y, b_z, b_dir, b_dir, b_dir)


def get_solution():
    # SEED SOLUTION - CENTER OF FIRST PLANE [x, y, z] AND DIRECTION ALONG THE BEAM [0, 0, [+|-] 1] 
    x0 = get_x0(single_hits_df.iloc[0], geom_df)    
    
    # RUNNING OPTIMIZING METHODS TO GET SOLUTION
    METHODS = ['Powell', 'Nelder-Mead']
    
    method = 'SLSQP'
    solution = minimize(objective, x0, method=method, constraints=get_constraints(), bounds=get_bounds())
    
    if solution.success != True:
        nelder_solution = minimize(objective, x0, method='Nelder-Mead', constraints=get_constraints(), bounds=get_bounds())
        
        solution = nelder_solution
        method = 'Nelder-Mead'
        
        if nelder_solution.success and nelder_solution.fun < 100.0:
            method = 'Nelder'
            solution = nelder_solution
        else:
            powell_solution = minimize(objective, x0, method='Powell', constraints=get_constraints(), bounds=get_bounds())
            
            if powell_solution.fun < nelder_solution:
                method = 'Powell'
                solution = powell_solution
            else:
                method = 'Nelder'
                solution = nelder_solution
    
    return (solution, method)

# %% [markdown]
# ### Itaration over Events and Group with single tracking

# %%
# HELP VARIABLES
row_number = 0
glob_max_hit_dist = 0.0
true_max_distance = 0.0
false_max_distance = 0.0


# FOR EACH EVENT AND GROUP CALCULATE LINE
for index, row in single_groups_df.iterrows():
#     if row_number < 1980:
#         row_number = row_number + 1
#         continue
    
    # GETTING HITS FOR SPECIFIED GROUP AND EVENT
    eventID, groupID = row['eventID'], row['groupID']
    single_hits_df = single_df.loc[(single_df['eventID'] == eventID) & (single_df['groupID'] == groupID)]
    
    # APPLYING Z TRANSLATION --> WE DO NOT WANT SUCH BIG NUMBERS (|Z| ~ 210 000 [mm])
    if groupID > 3:
        DET_Z_TRANSLATION = -210000
    else:
        DET_Z_TRANSLATION = 210000

    # GET LINES REPRESENTING HITS IN RPS
    LINE_SET = get_hit_lines(single_hits_df, geom_df)  
    
    # GET FITTED LINE AND METHOD USED FOR FITTING
    solution, method = get_solution()
    
    # UPDATE STATISTICS
    if solution.success == True:
        true_max_distance = np.maximum(true_max_distance, solution.fun)
    else:
        false_max_distance = np.maximum(false_max_distance, solution.fun)
                
    
    distances = [ Line(params=solution.x).distance(line) for line in LINE_SET]
    distance_sum = np.sum(distances)
    max_hit_dist = np.amax(distances)
    glob_max_hit_dist = np.maximum(glob_max_hit_dist, max_hit_dist)
    
    chi = chi2(solution.x)
    
    print("Row {} Event: {} Group: {} Method: {}  DistSum: {:.5f}  MDH: {:.5}  Success: {}  Chi: {:.5f}\tChiN: {:.5f}"
      .format(row_number, eventID, groupID, method, solution.fun, max_hit_dist, 
              solution.success, chi, chi / (len(LINE_SET) - 6)))
        
    row_number = row_number + 1
    

print("THE END")
# Out:
# Row 0 Event: 2 Group: 2 Method: Nelder  DistSum: 0.42049  MDH: 0.044624  Success: True  Chi: 2.50834	ChiN: 0.10906
# Row 1 Event: 2 Group: 4 Method: SLSQP  DistSum: 0.53292  MDH: 0.046286  Success: True  Chi: 3.70059	ChiN: 0.16090
# Row 2 Event: 3 Group: 1 Method: SLSQP  DistSum: 0.50122  MDH: 0.067381  Success: True  Chi: 3.75692	ChiN: 0.17077
# Row 3 Event: 3 Group: 2 Method: SLSQP  DistSum: 0.69759  MDH: 0.085794  Success: True  Chi: 7.82428	ChiN: 0.34019
# Row 4 Event: 3 Group: 4 Method: SLSQP  DistSum: 0.49803  MDH: 0.055625  Success: True  Chi: 2.99785	ChiN: 0.12491
# Row 5 Event: 4 Group: 2 Method: SLSQP  DistSum: 0.71539  MDH: 0.057979  Success: True  Chi: 6.19299	ChiN: 0.28150
# Row 6 Event: 5 Group: 1 Method: Nelder  DistSum: 0.78325  MDH: 0.10546  Success: True  Chi: 9.28667	ChiN: 0.40377
# Row 7 Event: 5 Group: 5 Method: SLSQP  DistSum: 0.58450  MDH: 0.055528  Success: True  Chi: 4.50851	ChiN: 0.19602
# Row 8 Event: 6 Group: 1 Method: SLSQP  DistSum: 0.55677  MDH: 0.0535  Success: True  Chi: 3.72892	ChiN: 0.16950
# Row 9 Event: 6 Group: 5 Method: Powell  DistSum: 7.61974  MDH: 0.67707  Success: True  Chi: 840.42197	ChiN: 36.54009
# Row 10 Event: 7 Group: 1 Method: Powell  DistSum: 0.53216  MDH: 0.053116  Success: True  Chi: 3.67656	ChiN: 0.16712
# Row 11 Event: 7 Group: 5 Method: Nelder  DistSum: 0.67479  MDH: 0.087424  Success: True  Chi: 6.62499	ChiN: 0.28804
# Row 12 Event: 8 Group: 2 Method: SLSQP  DistSum: 0.80381  MDH: 0.12644  Success: True  Chi: 10.26428	ChiN: 0.42768
# Row 13 Event: 8 Group: 4 Method: SLSQP  DistSum: 0.53750  MDH: 0.044214  Success: True  Chi: 3.37324	ChiN: 0.14055
# Row 14 Event: 9 Group: 2 Method: SLSQP  DistSum: 0.63882  MDH: 0.078601  Success: True  Chi: 6.25542	ChiN: 0.27197
# Row 15 Event: 9 Group: 4 Method: Powell  DistSum: 12.18108  MDH: 0.92829  Success: True  Chi: 2069.94917	ChiN: 86.24788
# Row 16 Event: 10 Group: 1 Method: SLSQP  DistSum: 0.46181  MDH: 0.043674  Success: True  Chi: 2.65512	ChiN: 0.12069
# Row 17 Event: 10 Group: 5 Method: SLSQP  DistSum: 0.49216  MDH: 0.056577  Success: True  Chi: 3.09471	ChiN: 0.13455
# Row 18 Event: 11 Group: 2 Method: Powell  DistSum: 8.86636  MDH: 0.64653  Success: True  Chi: 1036.64704	ChiN: 45.07161
# Row 19 Event: 12 Group: 1 Method: Powell  DistSum: 0.46415  MDH: 0.054224  Success: True  Chi: 3.07601	ChiN: 0.14648
# Row 20 Event: 12 Group: 5 Method: SLSQP  DistSum: 0.64664  MDH: 0.0537  Success: True  Chi: 5.00162	ChiN: 0.21746
# Row 21 Event: 13 Group: 2 Method: SLSQP  DistSum: 0.77599  MDH: 0.085585  Success: True  Chi: 8.80639	ChiN: 0.40029
# Row 22 Event: 13 Group: 4 Method: Nelder  DistSum: 67.92483  MDH: 5.8  Success: True  Chi: 71640.63691	ChiN: 2985.02654
# Row 23 Event: 14 Group: 2 Method: SLSQP  DistSum: 0.65854  MDH: 0.059133  Success: True  Chi: 5.62342	ChiN: 0.24450
# Row 24 Event: 14 Group: 4 Method: SLSQP  DistSum: 0.74150  MDH: 0.18102  Success: True  Chi: 11.38057	ChiN: 0.45522
# Row 25 Event: 15 Group: 1 Method: Nelder  DistSum: 0.68202  MDH: 0.054108  Success: True  Chi: 5.67398	ChiN: 0.25791
# Row 26 Event: 15 Group: 5 Method: Powell  DistSum: 7.40717  MDH: 0.60914  Success: True  Chi: 768.32388	ChiN: 33.40539
# Row 27 Event: 16 Group: 2 Method: SLSQP  DistSum: 0.78005  MDH: 0.09418  Success: True  Chi: 10.47085	ChiN: 0.45525
# Row 28 Event: 16 Group: 4 Method: SLSQP  DistSum: 0.51398  MDH: 0.10202  Success: True  Chi: 4.67331	ChiN: 0.19472
# Row 29 Event: 17 Group: 2 Method: Nelder  DistSum: 3.06705  MDH: 0.28574  Success: True  Chi: 139.50953	ChiN: 6.06563
# Row 30 Event: 17 Group: 5 Method: SLSQP  DistSum: 0.49762  MDH: 0.1281  Success: True  Chi: 5.63948	ChiN: 0.23498
# Row 31 Event: 18 Group: 2 Method: Nelder  DistSum: 1.47858  MDH: 0.17941  Success: True  Chi: 34.49947	ChiN: 1.49998
# Row 32 Event: 18 Group: 4 Method: Nelder  DistSum: 68.56609  MDH: 5.582  Success: True  Chi: 69471.43889	ChiN: 2894.64329
# Row 33 Event: 19 Group: 1 Method: SLSQP  DistSum: 0.54348  MDH: 0.061914  Success: True  Chi: 4.41016	ChiN: 0.20046
# Row 34 Event: 20 Group: 2 Method: Nelder  DistSum: 43.07262  MDH: 3.3429  Success: True  Chi: 25839.56516	ChiN: 1076.64855
# Row 35 Event: 20 Group: 4 Method: Powell  DistSum: 9.17332  MDH: 0.71375  Success: True  Chi: 1142.25510	ChiN: 47.59396
# Row 36 Event: 21 Group: 1 Method: SLSQP  DistSum: 0.63003  MDH: 0.068828  Success: True  Chi: 5.93339	ChiN: 0.26970
# Row 37 Event: 21 Group: 5 Method: SLSQP  DistSum: 0.61506  MDH: 0.063695  Success: True  Chi: 6.07043	ChiN: 0.26393
# Row 38 Event: 22 Group: 1 Method: SLSQP  DistSum: 0.52492  MDH: 0.04887  Success: True  Chi: 3.79088	ChiN: 0.16482
# Row 39 Event: 22 Group: 5 Method: Nelder  DistSum: 1.01570  MDH: 0.13535  Success: True  Chi: 17.42720	ChiN: 0.72613
# Row 40 Event: 23 Group: 2 Method: Powell  DistSum: 7.52947  MDH: 0.63292  Success: True  Chi: 738.11834	ChiN: 32.09210
# Row 41 Event: 24 Group: 4 Method: SLSQP  DistSum: 0.46314  MDH: 0.043377  Success: True  Chi: 2.93485	ChiN: 0.15447
# Row 42 Event: 26 Group: 2 Method: Nelder  DistSum: 0.81056  MDH: 0.070838  Success: True  Chi: 8.92416	ChiN: 0.40564
# Row 43 Event: 26 Group: 4 Method: Nelder  DistSum: 56.82900  MDH: 4.5623  Success: True  Chi: 47333.80383	ChiN: 1972.24183
# Row 44 Event: 29 Group: 1 Method: Powell  DistSum: 0.60185  MDH: 0.11657  Success: True  Chi: 6.38026	ChiN: 0.29001
# Row 45 Event: 29 Group: 5 Method: SLSQP  DistSum: 0.42565  MDH: 0.040372  Success: True  Chi: 2.45858	ChiN: 0.10689
# Row 46 Event: 30 Group: 2 Method: SLSQP  DistSum: 0.53900  MDH: 0.054798  Success: True  Chi: 4.14933	ChiN: 0.18041
# Row 47 Event: 31 Group: 5 Method: Powell  DistSum: 6.77000  MDH: 0.54372  Success: True  Chi: 607.97024	ChiN: 28.95096
# Row 48 Event: 32 Group: 1 Method: SLSQP  DistSum: 0.44223  MDH: 0.043211  Success: True  Chi: 2.91107	ChiN: 0.13232
# Row 49 Event: 33 Group: 1 Method: SLSQP  DistSum: 0.60401  MDH: 0.082203  Success: True  Chi: 5.30137	ChiN: 0.24097
# Row 50 Event: 33 Group: 5 Method: Powell  DistSum: 7.97777  MDH: 0.64179  Success: True  Chi: 890.45637	ChiN: 38.71549
# Row 51 Event: 34 Group: 2 Method: SLSQP  DistSum: 0.85441  MDH: 0.17754  Success: True  Chi: 13.71590	ChiN: 0.57150
# Row 52 Event: 35 Group: 2 Method: Nelder  DistSum: 0.68754  MDH: 0.05433  Success: True  Chi: 5.68745	ChiN: 0.24728
# Row 53 Event: 35 Group: 4 Method: SLSQP  DistSum: 0.48307  MDH: 0.044836  Success: True  Chi: 2.89128	ChiN: 0.13142
# Row 54 Event: 36 Group: 2 Method: SLSQP  DistSum: 0.59169  MDH: 0.051351  Success: True  Chi: 4.37129	ChiN: 0.19006
# Row 55 Event: 38 Group: 2 Method: Powell  DistSum: 32.79254  MDH: 3.4174  Success: True  Chi: 17618.84387	ChiN: 766.03669
# Row 56 Event: 38 Group: 5 Method: Powell  DistSum: 8.35219  MDH: 0.67203  Success: True  Chi: 946.72852	ChiN: 41.16211
# Row 57 Event: 39 Group: 2 Method: Powell  DistSum: 11.10992  MDH: 0.94418  Success: True  Chi: 1749.68016	ChiN: 76.07305
# Row 58 Event: 39 Group: 4 Method: SLSQP  DistSum: 0.50214  MDH: 0.05327  Success: True  Chi: 3.36780	ChiN: 0.14032
# Row 59 Event: 41 Group: 1 Method: SLSQP  DistSum: 0.55470  MDH: 0.075128  Success: True  Chi: 4.46959	ChiN: 0.21284
# Row 60 Event: 42 Group: 1 Method: SLSQP  DistSum: 0.58953  MDH: 0.068671  Success: True  Chi: 5.76756	ChiN: 0.27465
# Row 61 Event: 42 Group: 5 Method: SLSQP  DistSum: 0.60284  MDH: 0.15345  Success: True  Chi: 7.97481	ChiN: 0.33228
# Row 62 Event: 43 Group: 2 Method: Powell  DistSum: 8.18528  MDH: 0.59076  Success: True  Chi: 870.87726	ChiN: 37.86423
# Row 63 Event: 43 Group: 4 Method: SLSQP  DistSum: 0.57105  MDH: 0.085633  Success: True  Chi: 5.82679	ChiN: 0.24278
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-46-3b64afc06e69> in <module>()
#      26
#      27     # GET FITTED LINE AND METHOD USED FOR FITTING
# ---> 28     solution, method = get_solution()
#      29
#      30     # UPDATE STATISTICS
#
# <ipython-input-45-03740345011f> in get_solution()
#      39
#      40     method = 'SLSQP'
# ---> 41     solution = minimize(objective, x0, method=method, constraints=get_constraints(), bounds=get_bounds())
#      42
#      43     if solution.success != True:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-slc6-gcc62-opt/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     456     elif meth == 'slsqp':
#     457         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 458                                constraints, callback=callback, **options)
#     459     elif meth == 'dogleg':
#     460         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-slc6-gcc62-opt/lib/python2.7/site-packages/scipy/optimize/slsqp.pyc in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     365
#     366             # Compute objective function
# --> 367             fx = func(x)
#     368             # Compute the constraints
#     369             if cons['eq']:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-slc6-gcc62-opt/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# <ipython-input-45-03740345011f> in objective(params)
#       2 def objective(params):
#       3     line = Line(params=params)                                  # CREATING FITTED LINE FROM PARAMS
# ----> 4     return np.sum([line.distance(other) for other in LINE_SET]) # SUM OF DISTANCES
#       5
#       6 # SEED FOR MINIMIZING
#
# <ipython-input-33-fe8054542788> in distance(self, other)
#      20
#      21     def distance(self, other):
# ---> 22         n_vector = np.cross(self.line_vector(), other.line_vector())
#      23         s_o_vector = np.array([self.x - other.x, self.y - other.y, self.z - other.z])
#      24         return np.linalg.norm( np.dot(n_vector, s_o_vector) ) / np.linalg.norm(n_vector)
#
# KeyboardInterrupt:
